# %%
from bs4 import BeautifulSoup
import re

doc = "<html><head><title>Parul University</title></head> <body><p>Welcome to Advanced Python class</p><em>Hope you enjoyed! </em> </body> </html>"
soup = BeautifulSoup(doc,"html.parser")
#print(soup.prettify())

print(soup.head.next.text)
# Out:
# Parul University

# %%
from bs4 import BeautifulSoup
sibling_soup = BeautifulSoup("<a><b>text1</b><c>text2</c></b></a>","html.parser")
print(sibling_soup.b.next_sibling)
# Out:
# <c>text2</c>

# %%
from bs4 import BeautifulSoup
import re
import urllib.request as ur
url = "https://pythonprogramming.net/"
http = ur.urlopen(url)
html = http.read().decode()
soup = BeautifulSoup(html,"html.parser")
tag = soup.find_all("a", limit= 10)
#print(tag)
for item in tag:
    additional_url = item.get("href")
    if additional_url.startswith("http") or additional_url.startswith("https"):
        continue
    print(additional_url)
    new_url = url + str(additional_url)
    print(new_url)
    http = ur.urlopen(new_url)
    content = http.read().decode()
    soup_new = BeautifulSoup(content,"html.parser")
    title_new = soup_new("body")
    for item_new in title_new:
        print(item_new.get_text())
# Out:
# /
# https://pythonprogramming.net//
#
#
#
#
#
#
#
# search
#
#
#
#
#
# Home
# +=1
#
# Support the Content
# Community
# Log in
# Sign up
#
#
#
#
#
#
#
# Home
# +=1
#
# Support the Content
# Community
# Log in
# Sign up
#
#
#
#
#
#
#
#
#
# Materialize.toast('Chat with us on Discord:<a href="https://discord.gg/sentdex" target="blank"><button style="margin-bottom:5px" class="btn btn-sm">Join</button></a>', 4000)
#
#
#
#
#
#
#
# Machine Learning
#
#
# Employ both supervised and unsupervised machine learning, to make predictions or to understand data.
#
#
# View
#
#
#
#
#
#
#
#
#
# Data Analysis
#
#
# Learn how to use Python with Pandas, Matplotlib, and other modules to gather insights from and about your data.
#
#
# View
#
#
#
#
#
#
#
#
#
# Quantum Computer Programming
#
#
# Learn the basics and concepts of working with quantum computers and qubits through practical applications and the Qiskit package.
#
#
# Start
#
#
#
#
#
#
#
#
#
#
#
# Game Development
#
#
# ...

# %%
import urllib.request as ur
from bs4 import BeautifulSoup
http = ur.urlopen("https://www.pythonhow.com/example.html")
data = http.read().decode()
#print(data)
soup = BeautifulSoup(data,"html.parser")
divs = soup.find_all("div",limit=2)
siblings = divs[1].find_previous_siblings()
print(siblings)
# Out:
# [<div class="cities">
# <h2>London</h2>
# <p>London is the capital of England and it's been a British settlement since 2000 years ago. </p>
# </div>, <h1 align="center"> Here are three big cities </h1>]

# %%
import urllib.request as ur
from bs4 import BeautifulSoup
rutvik = ur.urlopen("https://www.pythonhow.com/example.html")
data = rutvik.read().decode()
#print(data)
yas = BeautifulSoup(data,"html.parser")
all = yas.find_all("div",{"class":"cities"})
print(type(all))
all_u =all[0]
print(all_u("h2")[0].text)
# Out:
# <class 'bs4.element.ResultSet'>
# London

# %%
import urllib.request as ur
from bs4 import BeautifulSoup
rutvik = ur.urlopen("https://www.pythonhow.com/example.html")
data = rutvik.read().decode()
#print(data)
yas = BeautifulSoup(data,"html.parser")
all = yas("div",{"class":"cities"})
print(type(all))
all_u =all[0]
print(all_u("h2")[0].text)
# Out:
# <class 'bs4.element.ResultSet'>
# London

# %%
from bs4 import BeautifulSoup
import re

doc = '''<html><head><title>Page title</title></head>
       <body><p id="firstpara" align="center">This is paragraph <b>one</b>
       <p id="secondpara" align="blah">This is paragraph <b>two</b>
       </html>'''

soup = BeautifulSoup(doc,"html.parser")
head = soup.contents[0].contents[0] 
print(head.name)
# Out:
# head

# %%
import urllib.request as ur
from bs4 import BeautifulSoup

r=ur.urlopen("http://pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/")
c=r.read().decode()
#print(c)


soup=BeautifulSoup(c,"html.parser")
divs= soup("h4",{"class":"propPrice"})
for item in divs:
    print(item.text.strip())
# Out:
# $725,000
# $452,900
# $396,900
# $389,900
# $254,000
# $252,900
# $210,000
# $209,000
# $199,900
# $196,900

# %%
import urllib.request as ur
from bs4 import BeautifulSoup
page_nr = 3
l=[]
base_url="http://pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s="
for page in range(0,int(page_nr)*10,10):
    r=ur.urlopen(base_url+str(page)+".html")
    c=r.read().decode()
    #c=r.json()["list"]
    soup=BeautifulSoup(c,"html.parser")
    all=soup.find_all("div",{"class":"propertyRow"})
    for item in all:
        d={}
        d["Address"]=item.find_all("span",{"class","propAddressCollapse"})[0].text
        try:
            d["Locality"]=item.find_all("span",{"class","propAddressCollapse"})[1].text
        except:
            d["Locality"]=None
        d["Price"]=item.find("h4",{"class","propPrice"}).text.strip()
        try:
            d["Beds"]=item.find("span",{"class","infoBed"}).find("b").text
        except:
            d["Beds"]=None
    
        try:
            d["Area"]=item.find("span",{"class","infoSqFt"}).find("b").text
        except:
            d["Area"]=None
    
        try:
            d["Full Baths"]=item.find("span",{"class","infoValueFullBath"}).find("b").text
        except:
            d["Full Baths"]=None

        try:
            d["Half Baths"]=item.find("span",{"class","infoValueHalfBath"}).find("b").text
        except:
            d["Half Baths"]=None
        for column_group in item.find_all("div",{"class":"columnGroup"}):
            for feature_group, feature_name in zip(column_group.find_all("span",{"class":"featureGroup"}),column_group.find_all("span",{"class":"featureName"})):
                if "Lot Size" in feature_group.text:
                    d["Lot Size"]=feature_name.text
        l.append(d)

# %%
l
# Out:
# [{'Address': '0 Gateway',
#   'Area': None,
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$725,000'},
#  {'Address': '1003 Winchester Blvd.',
#   'Area': None,
#   'Beds': '4',
#   'Full Baths': '4',
#   'Half Baths': None,
#   'Locality': 'Rock Springs, WY 82901',
#   'Lot Size': '0.21 Acres',
#   'Price': '$452,900'},
#  {'Address': '600 Talladega',
#   'Area': '3,154',
#   'Beds': '5',
#   'Full Baths': '3',
#   'Half Baths': None,
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$396,900'},
#  {'Address': '3239 Spearhead Way',
#   'Area': '3,076',
#   'Beds': '4',
#   'Full Baths': '3',
#   'Half Baths': '1',
#   'Locality': 'Rock Springs, WY 82901',
#   'Lot Size': 'Under 1/2 Acre, ',
#   'Price': '$389,900'},
#  {'Address': '522 Emerald Street',
#   'Area': '1,172',
#   'Beds': '3',
#   'Full Baths': '3',
#   'Half Baths': None,
#   'Locality': 'Rock Springs, WY 82901',
# ...

# %%
import pandas
df=pandas.DataFrame(l)

# %%
df
# Out:
#                           Address   Area  Beds Full Baths Half Baths  \
# 0                       0 Gateway   None  None       None       None
# 1           1003 Winchester Blvd.   None     4          4       None
# 2                   600 Talladega  3,154     5          3       None
# 3              3239 Spearhead Way  3,076     4          3          1
# 4              522 Emerald Street  1,172     3          3       None
# 5            1302 Veteran's Drive  1,932     4          2       None
# 6                1021 Cypress Cir  1,676     4          3       None
# 7                  913 Madison Dr  1,344     3          2       None
# 8               1344 Teton Street  1,920     3          2       None
# 9                  4 Minnies Lane  1,664     3          2       None
# 10                  9339 Sd 26900  2,560  None       None       None
# 11               RR674P13 Hwy 377  2,000  None       None       None
# 12                       0 Hwy 41   None  None       None       None
# ...

# %%
df.to_csv(r"C:\Users\Rutvik Mehta\Desktop\rutvik\cps ppt videos programs\Output.csv")
